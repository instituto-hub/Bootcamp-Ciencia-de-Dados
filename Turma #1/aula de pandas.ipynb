# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 200
np.set_printoptions(precision=4, suppress=True)

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])

# %%
np.log(obj[obj > 1])
# Out:
# 0    1.386294
# 1    1.945910
# 3    1.098612
# dtype: float64

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000, 'Thais': None}

# %%
obj3 = pd.Series(sdata)

# %%
obj3.isnull()
# Out:
# Ohio      False
# Texas     False
# Oregon    False
# Utah      False
# Thais      True
# dtype: bool

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada', 'Cidade de Papel'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003, 2000],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2, None]}
frame = pd.DataFrame(data)

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame['coluna_nova'] = 0

# %%
frame['state']
# Out:
# 0               Ohio
# 1               Ohio
# 2               Ohio
# 3             Nevada
# 4             Nevada
# 5             Nevada
# 6    Cidade de Papel
# Name: state, dtype: object

# %%
frame['coluna_nova'] = frame.state == 'Cidade de Papel'

# %%
frame = frame[['state', 'year', 'pop', 'coluna_nova', 'eastern']]

# %%
frame
# Out:
#              state  year  pop  coluna_nova  eastern
# 0             Ohio  2000  1.5        False     True
# 1             Ohio  2001  1.7        False     True
# 2             Ohio  2002  3.6        False     True
# 3           Nevada  2001  2.4        False    False
# 4           Nevada  2002  2.9        False    False
# 5           Nevada  2003  3.2        False    False
# 6  Cidade de Papel  2000  NaN         True    False

# %%
frame[frame['year'] >= 2002]
# Out:
#     state  year  pop  coluna_nova  eastern
# 2    Ohio  2002  3.6        False     True
# 4  Nevada  2002  2.9        False    False
# 5  Nevada  2003  3.2        False    False

# %%
ex_frame = pd.read_csv('data/exemplo5.csv', na_values=['NULL'])

# %%
ex_frame
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
path = 'data/title.ratings 2.tsv'
path_aka = 'data/title.akas.tsv'

# %%
filmes_frame = pd.read_csv(path, na_values=['NULL'], sep='\t')

# %%
filmes_frame.tail()
# Out:
#             tconst  averageRating  numVotes
# 1659591  tt9916720            5.3        43
# 1659592  tt9916766            6.7        11
# 1659593  tt9916766            6.7        11
# 1659594  tt9916778            6.9        16
# 1659595  tt9916778            6.9        16

# %%
aka_frame = pd.read_csv(path_aka, na_values=['NULL'], sep='\t', low_memory=False)

# %%
aka_frame.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1  Carmencita - spanyol tánc     HU       \N
# 1  tt0000001         2                 Καρμενσίτα     GR       \N
# 2  tt0000001         3                 Карменсита     RU       \N
# 3  tt0000001         4                 Carmencita     US       \N
# 4  tt0000001         5                 Carmencita     \N       \N
#
#          types attributes isOriginalTitle
# 0  imdbDisplay         \N               0
# 1           \N         \N               0
# 2           \N         \N               0
# 3           \N         \N               0
# 4     original         \N               1

# %%
 filmes_frame.describe()
# Out:
#        averageRating      numVotes
# count   1.659596e+06  1.659596e+06
# mean    6.883185e+00  9.579288e+02
# std     1.402848e+00  1.579450e+04
# min     1.000000e+00  5.000000e+00
# 25%     6.100000e+00  9.000000e+00
# 50%     7.100000e+00  2.000000e+01
# 75%     7.900000e+00  7.600000e+01
# max     1.000000e+01  2.164668e+06

# %% [markdown]
# ## H3 :  top 10 filmes mais populares

# %%
filmes_mais_populares = np.array(filmes_frame.sort_values(by=['numVotes'], 
                                                          ascending=False)['tconst']
                                 .unique()[:10])

# %%
filmes_mais_populares
# Out:
# array(['tt0111161', 'tt0468569', 'tt1375666', 'tt0137523', 'tt0110912',
#        'tt0109830', 'tt0944947', 'tt0133093', 'tt0120737', 'tt0167260'],
#       dtype=object)

# %%
aka_frame[aka_frame['titleId'] == 'tt1375666'][:10]
# Out:
#            titleId  ordering           title region language        types  \
# 6239685  tt1375666        10          Начало     RU       \N           \N
# 6239686  tt1375666        11      Pirmsakums     LV       \N  imdbDisplay
# 6239687  tt1375666        12  Oliver's Arrow     US       \N           \N
# 6239688  tt1375666        13       Inception     BE       \N  imdbDisplay
# 6239689  tt1375666        14          Origen     ES       \N  imdbDisplay
# 6239690  tt1375666        15       Inception     DE       \N  imdbDisplay
# 6239691  tt1375666        16       Inception     FR       \N  imdbDisplay
# 6239692  tt1375666        17        A Origem     PT       \N           \N
# 6239693  tt1375666        18       Inception     IT       \N  imdbDisplay
# 6239694  tt1375666        19         Pradžia     LT       \N           \N
#
#                  attributes isOriginalTitle
# 6239685                  \N               0
# 6239686                  \N               0
# ...

# %%
aka_frame[
        (aka_frame['titleId'].isin(filmes_mais_popu lares)) 
        & 
        (aka_frame['region'] == 'US')
        ]
# Out:
#            titleId  ordering  \
# 643514   tt0109830        24
# 643531   tt0109830         4
# 650432   tt0110912        15
# 650462   tt0110912        42
# 650473   tt0110912         7
# 652167   tt0111161        10
# 652188   tt0111161         2
# 652219   tt0111161        58
# 679647   tt0120737        37
# 679650   tt0120737         3
# 679673   tt0120737         8
# 715572   tt0133093         2
# 726675   tt0137523        28
# 800824   tt0167260        37
# 800827   tt0167260         3
# 1416493  tt0468569        21
# 1416498  tt0468569        26
# 1416499  tt0468569        27
# 1416504  tt0468569        31
# 1416527  tt0468569        52
# 1416528  tt0468569        53
# 1416534  tt0468569         8
# 1416535  tt0468569         9
# 2504963  tt0944947         3
# 2504967  tt0944947        43
# 2504971  tt0944947         4
# 6239687  tt1375666        12
# 6239696  tt1375666        20
# 6239700  tt1375666        24
# 6239733  tt1375666         9
#
# ...
